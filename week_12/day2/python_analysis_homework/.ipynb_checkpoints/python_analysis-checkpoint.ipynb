# %%
import pandas as pd

# %%
drinks_content = pd.read_csv('starbucks_drinkMenu_expanded.csv')

# %%
drinks_content.shape
# Out:
# (242, 18)

# %%
drinks_content.head(5)
drinks_content.tail(5)
# Out:
#               Beverage_category                                      Beverage  \
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
#           Beverage_prep  Calories  Total Fat (g)  Trans Fat (g)   \
# 237             Soymilk       320            3 2             0.4
# 238    Tall Nonfat Milk       170            0.1             0.1
# 239          Whole Milk       200            3.5             2.0
# 240             Soymilk       180            1.5             0.2
# 241  Grande Nonfat Milk       240            0.1             0.1
#
#      Saturated Fat (g)   Sodium (mg)   Total Carbohydrates (g)   \
# ...

# %%
drinks_content.columns
# Out:
# Index(['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories',
#        ' Total Fat (g)', 'Trans Fat (g) ', 'Saturated Fat (g)', ' Sodium (mg)',
#        ' Total Carbohydrates (g) ', 'Cholesterol (mg)', ' Dietary Fibre (g)',
#        ' Sugars (g)', ' Protein (g) ', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
#        ' Calcium (% DV) ', 'Iron (% DV) ', 'Caffeine (mg)'],
#       dtype='object')

# %%
drinks_content.describe()
# Out:
#          Calories  Trans Fat (g)   Saturated Fat (g)   Sodium (mg)  \
# count  242.000000      242.000000         242.000000    242.000000
# mean   193.871901        1.307025           0.037603      6.363636
# std    102.863303        1.640259           0.071377      8.630257
# min      0.000000        0.000000           0.000000      0.000000
# 25%    120.000000        0.100000           0.000000      0.000000
# 50%    185.000000        0.500000           0.000000      5.000000
# 75%    260.000000        2.000000           0.100000     10.000000
# max    510.000000        9.000000           0.300000     40.000000
#
#         Total Carbohydrates (g)   Cholesterol (mg)   Dietary Fibre (g)  \
# count                 242.000000        242.000000          242.000000
# mean                  128.884298         35.991736            0.805785
# std                    82.303223         20.795186            1.445944
# min                     0.000000          0.000000            0.000000
# ...

# %%
drinks_content['Calories'].mean()
# Out:
# 193.87190082644628

# %%
drinks_content['Calories'].max()
# Out:
# 510

# %%
drinks_content['Calories'].min()
# Out:
# 0

# %% [markdown]
# Select the variables Beverage_category, Beverage, Beverage prep and Calories from the drinks_content data frame, and assign the selected columns to a new data frame called drinks. Check if there are any missing values anywhere in the data, and drop any rows containing them if there are.

# %%
drinks = drinks_content.loc[:, ['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories']].copy()
drinks
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
drinks.isna().sum()
#no NAs values
# Out:
# Beverage_category    0
# Beverage             0
# Beverage_prep        0
# Calories             0
# dtype: int64

# %% [markdown]
# In your drinks dataframe create a new variable (column) called calorie_diff, which stores the difference between 135 calories (135 calories = 10 cubes of sugar!) and the calories in each drink. (Hint: you’ll want to subtract the calories from 135 to see which drink have more or less than 10 cups of sugar).

# %%
drinks['calorie_diff'] = 135 - drinks['Calories']
drinks
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %% [markdown]
# Summarise the mean number of calories in each beverage_category. Which 3 category of drinks have the most calories? Which 3 drinks have the least? Write a small summary of your findings.

# %%
avg_cal = drinks.groupby('Beverage_category')['Calories'].mean().reset_index(name = 'avg_calorie')
avg_cal
# Out:
#                    Beverage_category  avg_calorie
# 0            Classic Espresso Drinks   140.172414
# 1                             Coffee     4.250000
# 2        Frappuccino® Blended Coffee   276.944444
# 3         Frappuccino® Blended Crème   233.076923
# 4  Frappuccino® Light Blended Coffee   162.500000
# 5              Shaken Iced Beverages   114.444444
# 6          Signature Espresso Drinks   250.000000
# 7                          Smoothies   282.222222
# 8                   Tazo® Tea Drinks   177.307692

# %%
avg_cal.sort_values('avg_calorie', ascending = False).head(3)
# Out:
#              Beverage_category  avg_calorie
# 7                    Smoothies   282.222222
# 2  Frappuccino® Blended Coffee   276.944444
# 6    Signature Espresso Drinks   250.000000

# %%
avg_cal.sort_values('avg_calorie', ascending = False).tail(3)
# Out:
#          Beverage_category  avg_calorie
# 0  Classic Espresso Drinks   140.172414
# 5    Shaken Iced Beverages   114.444444
# 1                   Coffee     4.250000

# %% [markdown]
# Which Beverage_prep type contains more than the average calories of all drinks? (Hint: to answer this, you’ll have to first figure out what the average calories across all drinks are, and then use that as a filter for the grouped Beverage_prep data).

# %%
drinks['Calories'].mean()
# Out:
# 193.87190082644628

# %%
avg_cal[(avg_cal['avg_calorie'] > (drinks['Calories'].mean()))]
# Out:
#              Beverage_category  avg_calorie
# 2  Frappuccino® Blended Coffee   276.944444
# 3   Frappuccino® Blended Crème   233.076923
# 6    Signature Espresso Drinks   250.000000
# 7                    Smoothies   282.222222

# %% [markdown]
# Harder - Which is the best type of coffee drink to get if you’re worried about consuming too many calories?

# %%
avg_cal.sort_values('avg_calorie').head(1)
#just plain coffee?
# Out:
#   Beverage_category  avg_calorie
# 1            Coffee         4.25

# %% [markdown]
# Filter the dataset drinks so we only take "Classic Espresso Drinks", and save this in a new data frame called espresso_drinks.

# %%
espresso_drinks = drinks_content.loc[drinks_content['Beverage_category']== 'Classic Espresso Drinks',:].copy()
espresso_drinks
# Out:
#           Beverage_category                                  Beverage  \
# 4   Classic Espresso Drinks                               Caffè Latte
# 5   Classic Espresso Drinks                               Caffè Latte
# 6   Classic Espresso Drinks                               Caffè Latte
# 7   Classic Espresso Drinks                               Caffè Latte
# 8   Classic Espresso Drinks                               Caffè Latte
# 9   Classic Espresso Drinks                               Caffè Latte
# 10  Classic Espresso Drinks                               Caffè Latte
# 11  Classic Espresso Drinks                               Caffè Latte
# 12  Classic Espresso Drinks                               Caffè Latte
# 13  Classic Espresso Drinks                               Caffè Latte
# 14  Classic Espresso Drinks                               Caffè Latte
# 15  Classic Espresso Drinks                               Caffè Latte
# ...

# %% [markdown]
# Group your espresso_drinks data frame by the type of Beverage prep, and then find out the mean calories for each drink group.

# %%
espresso_avg = espresso_drinks.groupby('Beverage_prep')['Calories'].mean().reset_index(name = 'avg_calorie')
espresso_avg
# Out:
#          Beverage_prep  avg_calorie
# 0              2% Milk      184.375
# 1               Doppio       10.000
# 2               Grande       15.000
# 3   Grande Nonfat Milk      150.000
# 4                Short        5.000
# 5    Short Nonfat Milk       78.000
# 6                 Solo        5.000
# 7              Soymilk      151.250
# 8                 Tall       10.000
# 9     Tall Nonfat Milk      116.000
# 10               Venti       25.000
# 11   Venti Nonfat Milk      194.000

# %% [markdown]
# Get the same grouped mean Calories values as above, but this time sorted in descending order. (Hint: so you're able to sort the resulting groupby by the 'Calories' column you will want to ensure you get back a dataframe and not a series)

# %%
espresso_avg.sort_values('avg_calorie', ascending = False)
# Out:
#          Beverage_prep  avg_calorie
# 11   Venti Nonfat Milk      194.000
# 0              2% Milk      184.375
# 7              Soymilk      151.250
# 3   Grande Nonfat Milk      150.000
# 9     Tall Nonfat Milk      116.000
# 5    Short Nonfat Milk       78.000
# 10               Venti       25.000
# 2               Grande       15.000
# 1               Doppio       10.000
# 8                 Tall       10.000
# 4                Short        5.000
# 6                 Solo        5.000

# %%
drinks_content.loc[[drinks_content[' Total Carbohydrates (g) '].idxmax(), drinks_content[' Total Carbohydrates (g) '].idxmin()]]
# Out:
#                Beverage_category                           Beverage  \
# 214  Frappuccino® Blended Coffee  Java Chip (Without Whipped Cream)
# 56       Classic Espresso Drinks                           Espresso
#
#          Beverage_prep  Calories  Total Fat (g)  Trans Fat (g)   \
# 214  Venti Nonfat Milk       420              5             4.0
# 56                Solo         5              0             0.0
#
#      Saturated Fat (g)   Sodium (mg)   Total Carbohydrates (g)   \
# 214                0.0             5                        340
# 56                 0.0             0                          0
#
#      Cholesterol (mg)   Dietary Fibre (g)   Sugars (g)   Protein (g)   \
# 214                90                   2           84            7.0
# 56                  1                   0            0            0.4
#
#     Vitamin A (% DV)  Vitamin C (% DV)  Calcium (% DV)  Iron (% DV)   \
# 214               10%               0%              20%          35%
# ...

# %%
drinks_content.columns
# Out:
# Index(['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories',
#        ' Total Fat (g)', 'Trans Fat (g) ', 'Saturated Fat (g)', ' Sodium (mg)',
#        ' Total Carbohydrates (g) ', 'Cholesterol (mg)', ' Dietary Fibre (g)',
#        ' Sugars (g)', ' Protein (g) ', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
#        ' Calcium (% DV) ', 'Iron (% DV) ', 'Caffeine (mg)'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.scatterplot(x =  'Saturated Fat (g)', y = 'Calories',color = 'aqua', data = drinks_content)

# %%
plt.hist(x = 'Beverage_category', data = drinks_content)
plt.xticks(rotation = 45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8], <a list of 9 Text major ticklabel objects>)

# %%
sns.barplot(y = 'Beverage_category', x = 'Calories', orient = 'h', data = drinks_content, ci = False)

# %%
sns.scatterplot(x = 'Cholesterol (mg)',y = 'Calories', data = drinks_content, palette = 'mako_r', hue = 'Trans Fat (g) ')

# %%
sns.scatterplot(x = 'Cholesterol (mg)',y = 'Calories', data = drinks_content, palette = 'mako_r', size = 'Trans Fat (g) ')
